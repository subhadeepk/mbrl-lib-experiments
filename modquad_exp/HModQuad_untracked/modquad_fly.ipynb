# %% [markdown]
# #### Note: This example is compatible with versions v0.2.1dev or higher (i.e., up to date with GitHub). For instructions on how to run with latest pip stable versions (<=v0.1.5), see [this](https://github.com/facebookresearch/mbrl-lib/blob/main/notebooks/pets_example_v0.1.5.ipynb) notebook.

# %% [markdown]
# # Preview
#
# In this example, we are going to use our toolbox to write the [PETS](https://arxiv.org/pdf/1805.12114.pdf) algorithm (Chua at al., 2018), and use it to solve a continuous version of the cartpole environment. PETS is a model-based algorithm that consists of two main components: an ensemble of probabilistic models (each a feed-forward neural network), and a planner using the [Cross-Entropy Method](https://people.smp.uq.edu.au/DirkKroese/ps/aortut.pdf) (de Boer et al., 2004).
#
# A basic implementation of this algorithm consists of the following sequence of steps:
#
# 1. Gather data using an exploration policy
# 2. Repeat:<br>
#   2.1. Train the dynamics model using all available data.<br>
#   2.2. Do a trajectory on the environment, choosing actions with the planner, using the dynamics model to simulate environment transitions.
#
# The ensemble model is trained to predict the environment's dynamics, and the planner tries to find high-reward trajectories over the model dynamics.
#
# To implement this using `MBRL-Lib`, we will use an ensemble of neural networks (NNs) modelling Gaussian distributions (available in the [mbrl.models](https://luisenp.github.io/mbrl-lib/models.html#mbrl.models.GaussianMLP) module), and a trajectory optimizer agent that uses CEM (available in the [mbrl.planning](https://luisenp.github.io/mbrl-lib/planning.html#mbrl.planning.TrajectoryOptimizerAgent) module). We will also rely on several of the utilities available in the [mbrl.util](https://luisenp.github.io/mbrl-lib/util.html) module. Finally, we will wrap the dynamics model into a [gym-like environment](https://luisenp.github.io/mbrl-lib/models.html#mbrl.models.ModelEnv) over which we can plan action sequences.

# %%
from IPython import display
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import torch
import omegaconf

import modquad_copp_env as modquad_env
import mbrl.env.reward_fns as reward_fns
import mbrl.env.termination_fns as termination_fns
import mbrl.models as models
import mbrl.planning as planning
import mbrl.util.common as common_util
import mbrl.util as util
import modquad_utils 
import time


# %load_ext autoreload
# %autoreload 2

mpl.rcParams.update({"font.size": 16})

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Creating the environment
#
# First we instantiate the environment and specify which reward function and termination function to use with the gym-like environment wrapper, along with some utility objects. The termination function tells the wrapper if an observation should cause an episode to end or not, and it is an input used in some algorithms, like [MBPO](https://github.com/JannerM/mbpo/blob/master/mbpo/static/halfcheetah.py). The reward function is used to compute the value of the reward given an observation, and it's used by some algorithms, like [PETS](https://github.com/kchua/handful-of-trials/blob/77fd8802cc30b7683f0227c90527b5414c0df34c/dmbrl/controllers/MPC.py#L65).

# %%
seed = 0
env = modquad_env.ModQuadEnv()
# time.sleep(2)
# env.run_gym_simulation()
# time.sleep(5)
# env.end_simulation()
# time.sleep(5)
# env.reset()
# env.run_gym_simulation()
# time.sleep(5)
# env.end_simulation()
# time.sleep(5)
# env.reset()
# env.get_replay_buffer()
# replay_buffer_sim = env.get_replay_buffer()
# print(replay_buffer_sim)
# env.reset(seed)
rng = np.random.default_rng(seed=0)
generator = torch.Generator(device=device)
generator.manual_seed(seed)
obs_shape = env.observation_space.shape
act_shape = env.action_space.shape

# This functions allows the model to evaluate the true rewards given an observation 
reward_fn = modquad_utils.modquad_reward
# This function allows the model to know if an observation should make the episode end
term_fn = modquad_utils.modquad_termination
# Out:
# Connecting to CoppeliaSim...
# Connected!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 seed = 0
# ----> 2 env = modquad_env.ModQuadEnv()
#       3 # time.sleep(2)
#       4 # env.run_gym_simulation()
#       5 # time.sleep(5)
#    (...)
#      16 # print(replay_buffer_sim)
#      17 # env.reset(seed)
#      18 rng = np.random.default_rng(seed=0)
#
# File c:\Users\ksubh\OneDrive\Documents\SwarmsLab_RL\Summer 25\Implementations\mbrl_lib_maintained\mbrl-lib-experiments\modquad_exp\HModQuad_sim\modquad_copp_env.py:31, in ModQuadEnv.__init__(self, render_mode, max_steps)
#      28 mlb.sim.simxFinish(-1)  # Just in case, close all old connections
#      29 self.client_id = mlb.sim.simxStart('127.0.0.1', 19997, True, True, 5000, 5)
# ---> 31 self.reset()
#
# File c:\Users\ksubh\OneDrive\Documents\SwarmsLab_RL\Summer 25\Implementations\mbrl_lib_maintained\mbrl-lib-experiments\modquad_exp\HModQuad_sim\modquad_copp_env.py:47, in ModQuadEnv.reset(self, seed, options)
#      45     self.sim_Flag = True
#      46     # print(self.client_id)
# ---> 47     self.robot = mlb.Robot(
#      48             'MultiRotor', self.client_id,
#      49             ['/propeller{}'.format(i+1) for i in range(8)],
#      50             mlb.PID_param(
#      51                 mass=0.32, inertia=0.03,
#      52                 KZ=(5.0, 3.5, 0.0),
#      53                 KX=(2.0, 3.0, 0.0),
#      54                 KY=(0.2, 0.6, 0.0),
#      55                 KR=(1.5, 0.8, 0.0),
#      56                 KP=(0.8, 0.6, 0.0),
#      57                 KYAW=(-0.6, -0.5, 0.0)
#      58             )
#      59         )
#      60     self.target = mlb.Robot('DesiredBox', self.client_id)
#      62 else:
#
# File c:\Users\ksubh\OneDrive\Documents\SwarmsLab_RL\Summer 25\Implementations\mbrl_lib_maintained\mbrl-lib-experiments\modquad_exp\HModQuad_sim\meta_learning_base.py:27, in Robot.__init__(self, frame_name, motor_names, control_param, client_id)
#      24 else:
#      25     self.client_id = self.open_connection()
# ---> 27 self.motors = self._get_handlers(motor_names)
#      29 # Robot frame
#      30 self.frame = self._get_handler(frame_name)
#
# File c:\Users\ksubh\OneDrive\Documents\SwarmsLab_RL\Summer 25\Implementations\mbrl_lib_maintained\mbrl-lib-experiments\modquad_exp\HModQuad_sim\meta_learning_base.py:79, in Robot._get_handlers(self, names)
#      77 handlers = []
#      78 if names is not None:
# ---> 79     for name in names:
#      80         handler = self._get_handler(name)
#      81         handlers.append(handler)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# # Hydra configuration
#
# MBRL-Lib uses [Hydra](https://github.com/facebookresearch/hydra) to manage configurations. For the purpose of this example, you can think of the configuration object as a dictionary with key/value pairs--and equivalent attributes--that specify the model and algorithmic options. Our toolbox expects the configuration object to be organized as follows:

# %%
trial_length = 200
num_trials = 10
ensemble_size = 5

# Everything with "???" indicates an option with a missing value.
# Our utility functions will fill in these details using the 
# environment information
cfg_dict = {
    # dynamics model configuration
    "dynamics_model": {
        "_target_": "mbrl.models.GaussianMLP",
        "device": device,
        "num_layers": 3,
        "ensemble_size": ensemble_size,
        "hid_size": 200,
        "in_size": "???",
        "out_size": "???",
        "deterministic": False,
        "propagation_method": "fixed_model",
        # can also configure activation function for GaussianMLP
        "activation_fn_cfg": {
            "_target_": "torch.nn.LeakyReLU",
            "negative_slope": 0.01
        }
    },
    # options for training the dynamics model
    "algorithm": {
        "learned_rewards": False,
        "target_is_delta": True,
        "normalize": True,
    },
    # these are experiment specific options
    "overrides": {
        "trial_length": trial_length,
        "num_steps": num_trials * trial_length,
        "model_batch_size": 32,
        "validation_ratio": 0.05
    }
}
cfg = omegaconf.OmegaConf.create(cfg_dict)

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note: </b> This example uses a probabilistic ensemble. You can also use a fully deterministic model with class GaussianMLP by setting ensemble_size=1, and deterministic=True. </div>

# %% [markdown]
# # Creating a dynamics model
#
# Given the configuration above, the following two lines of code create a wrapper for 1-D transition reward models, and a gym-like environment that wraps it, which we can use for simulating the real environment. The 1-D model wrapper takes care of creating input/output data tensors to the underlying NN model (by concatenating observations, actions and rewards appropriately), normalizing the input data to the model, and other data processing tasks (e.g., converting observation targets to deltas with respect to the input observation).

# %%
# Create a 1-D dynamics model for this environment
dynamics_model = common_util.create_one_dim_tr_model(cfg, obs_shape, act_shape)

# Create a gym-like environment to encapsulate the model
model_env = models.ModelEnv(env, dynamics_model, term_fn, reward_fn, generator=generator)

# %% [markdown]
# # Create a replay buffer
#
# We can create a replay buffer for this environment an configuration using the following method

# %%
replay_buffer = common_util.create_replay_buffer(cfg, obs_shape, act_shape, rng=rng)

# %% [markdown]
# We can now populate the replay buffer with random trajectories of a desired length, using a single function call to `util.rollout_agent_trajectories`. Note that we pass an agent of type `planning.RandomAgent` to generate the actions; however, this method accepts any agent that is a subclass of `planning.Agent`, allowing changing exploration strategies with minimal changes to the code.

# %%
replay_buffer_sim = env.get_replay_buffer()
# Out:
# ERROR: CANNOT SET POSITION W.R.T. -1 TO [0.  0.  0.1]
# ERROR: CANNOT SET DesiredBox ORIENTATION W.R.T. -1 TO [0.  0.  0.1]
# 1.0181808471679688
# 1.029656171798706
# 1.0452079772949219
# 1.0602591037750244
# 1.0772662162780762
# 1.092315435409546
# 1.1078250408172607
# 1.12333345413208
# 1.1383345127105713
# 1.1538338661193848
# 1.1693849563598633
# 1.1843674182891846
# 1.1993703842163086
# 1.2143828868865967
# 1.2323698997497559
# 1.2463786602020264
# 1.2598929405212402
# 1.275907278060913
# 1.2919063568115234
# 1.3075494766235352
# 1.3233263492584229
# 1.3367817401885986
# 1.352783441543579
# 1.3693263530731201
# 1.3854076862335205
# 1.4003362655639648
# 1.4143218994140625
# 1.430332899093628
# 1.448336124420166
# 1.4622485637664795
# 1.4776411056518555
# 1.4930052757263184
# 1.5080578327178955
# 1.5234360694885254
# 1.5394186973571777
# 1.554152011871338
# 60.04421353340149
# 60.05965542793274
# 60.075159311294556
# 60.09201669692993
# 60.106348514556885
# 60.12130403518677
# 60.13831067085266
# 60.15224766731262
# 60.16746973991394
# 60.182658195495605
# 60.198659896850586
# 60.21373653411865
# 60.22945976257324
# 60.24454975128174
# 60.260549783706665
# 60.27655243873596
# 60.292550563812256
# 60.30896258354187
# 60.3245804309845
# 60.340906620025635
# 60.355360984802246
# 60.3714280128479
# 60.3873565196991
# 60.402355909347534
# 60.418362617492676
# 60.43390250205994
# 60.44816207885742
# 60.46414804458618
# 60.48014235496521
# 60.49568724632263
# 60.51053261756897
# 60.52611780166626
# 60.5421142578125
# 60.558568477630615
# 60.574321031570435
# 60.59087610244751
# 60.605531454086304
# 60.621453523635864
# 60.637086153030396
# 60.653096437454224
# 60.67009258270264
# 60.68481159210205
# 60.69982957839966
# 60.71682119369507
# 60.73235511779785
# 60.74734926223755
# 60.76360630989075
# 60.77975535392761
# 60.795756578445435
# 60.809775590896606
# 60.825504779815674
# 60.84151482582092
# 60.85611438751221
# 60.871132373809814
# 60.88812017440796
# 60.902122020721436
# 60.91783165931702
# 60.9333758354187
# 60.95037651062012
# 60.964378118515015
# 60.97952651977539
# 60.99472212791443
# 61.01018166542053
# 61.02570700645447
# 61.04226350784302
# 61.05742406845093
# 61.07205605506897
# 61.08805727958679
# 61.10305619239807
# 61.1180694103241
# 61.13361310958862
# 61.150211811065674
# 61.16749119758606
# 61.181684732437134
# 61.19767880439758
# 61.21275734901428
# 61.22826623916626
# 61.24426794052124
# 61.26027703285217
# 61.27526664733887
# 61.2902672290802
# 61.30626630783081
# 61.32233452796936
# 61.33782339096069
# 61.35362267494202
# 61.36879277229309
# 61.384066104888916
# 61.39969086647034
# 61.41472268104553
# 61.4302339553833
# 61.446234703063965
# 61.46124005317688
# 61.47630429267883
# 61.49230694770813
# 61.507386445999146
# 61.52333307266235
# 61.5388445854187
# 61.55451035499573
# 61.5698823928833
# 61.58489990234375
# 61.602901220321655
# 61.6159143447876
# 61.63144612312317
# 61.64744305610657
# 61.66344356536865
# 61.678290367126465
# 61.69480347633362
# 61.710381507873535

# %%
# common_util.rollout_agent_trajectories( #integrate exploration to coppelia environment
#     env,
#     trial_length, # initial exploration steps
#     planning.RandomAgent(env),
#     {}, # keyword arguments to pass to agent.act()
#     replay_buffer=replay_buffer,
#     trial_length=trial_length
# )
env.end_simulation()
# replay_buffer_sim = env.get_replay_buffer()
for tr in replay_buffer_sim:
    obs, action, next_obs, reward, terminate, truncated = tr
    replay_buffer.add(obs, action, next_obs, reward, terminate, truncated)
print("# samples stored", replay_buffer.num_stored)
# Out:
# # samples stored 2000

# %% [markdown]
# # CEM Agent
#
# The following config object and the subsequent function call create an agent that can plan using the Cross-Entropy Method over the model environment created above. When calling `planning.create_trajectory_optim_agent_for_model`, we also specify how many particles to use when propagating model uncertainty, as well as the uncertainty propagation method, "fixed_model", which corresponds to the method TS$\infty$ in the PETS paper.

# %%
agent_cfg = omegaconf.OmegaConf.create({
    # this class evaluates many trajectories and picks the best one
    "_target_": "mbrl.planning.TrajectoryOptimizerAgent",
    "planning_horizon": 15,
    "replan_freq": 1,
    "verbose": False,
    "action_lb": "???",
    "action_ub": "???",
    # this is the optimizer to generate and choose a trajectory
    "optimizer_cfg": {
        "_target_": "mbrl.planning.CEMOptimizer",
        "num_iterations": 5,
        "elite_ratio": 0.1,
        "population_size": 500,
        "alpha": 0.1,
        "device": device,
        "lower_bound": "???",
        "upper_bound": "???",
        "return_mean_elites": True,
        "clipped_normal": False
    }
})

agent = planning.create_trajectory_optim_agent_for_model(
    model_env,
    agent_cfg,
    num_particles=20
)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 env.run_gym_simulation()
#
# NameError: name 'env' is not defined

# %% [markdown]
# # Running PETS

# %% [markdown]
# Having a model and an agent, we can now run PETS with a simple loop and a few function calls. The first code block creates a callback to pass to the model trainer to accumulate the training losses and validation scores observed. The second block is just a utility function to update the agent's visualization.

# %%
train_losses = []
val_scores = []

def train_callback(_model, _total_calls, _epoch, tr_loss, val_score, _best_val):
    train_losses.append(tr_loss)
    val_scores.append(val_score.mean().item())   # this returns val score per ensemble model

# %%
def update_axes(_axs, _frame, _text, _trial, _steps_trial, _all_rewards, force_update=False):
    if not force_update and (_steps_trial % 10 != 0):
        return
    _axs[0].imshow(_frame)
    _axs[0].set_xticks([])
    _axs[0].set_yticks([])
    _axs[1].clear()
    _axs[1].set_xlim([0, num_trials + .1])
    _axs[1].set_ylim([0, 200])
    _axs[1].set_xlabel("Trial")
    _axs[1].set_ylabel("Trial reward")
    _axs[1].plot(_all_rewards, 'bs-')
    _text.set_text(f"Trial {_trial + 1}: {_steps_trial} steps")
    display.display(plt.gcf())  
    display.clear_output(wait=True)

# %%
env.end_simulation()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The following lines implement the PETS algorithm. First, we create a model trainer and pass some hyperparameters for the optimizer (Adam), along with references to the model instance to use. Then we start a loop where we execute actions of ``agent`` in the environment and train the model at the beginning of the episode (by calling ``model_trainer.train()``. At every step in the loop, we execute an agent action in the environment and populate the replay buffer by calling ``util.step_env_and_add_to_buffer()``. Importantly, at the beginning of each episode we also call ``agent.reset()`` to clear any episode dependent cache; in the case of a ``TrajectoryOptimizerAgent``, this means clearing the previous action sequence found, which is shifted at every call to obtain an initial solution for the optimizer.
#
# The rest of the code is mostly bookkeeping to keep track of the total reward observed during each episode, and to make sure episodes terminate after some desired length. After running this code, you should see the agent reaching the maximum reward of 200 after a few episodes.

# %%
# Create a trainer for the model
model_trainer = models.ModelTrainer(dynamics_model, optim_lr=1e-3, weight_decay=5e-5)

# Create visualization objects
# fig, axs = plt.subplots(1, 2, figsize=(14, 3.75), gridspec_kw={"width_ratios": [1, 1]})
# ax_text = axs[0].text(300, 50, "")
    
# the states will encapsulate the desired trajectory \

# Main PETS loop
all_rewards = [0]
for trial in range(num_trials):
    obs, _ = env.reset(desired_traj = traj1)    
    agent.reset()
    
    terminated = False
    total_reward = 0.0
    steps_trial = 0
    # update_axes(axs, env.render(), ax_text, trial, steps_trial, all_rewards)
    while not terminated:
        # --------------- Model Training -----------------
        if steps_trial == 0:
            dynamics_model.update_normalizer(replay_buffer.get_all())  # update normalizer stats
            
            dataset_train, dataset_val = common_util.get_basic_buffer_iterators(
                replay_buffer,
                batch_size=cfg.overrides.model_batch_size,
                val_ratio=cfg.overrides.validation_ratio,
                ensemble_size=ensemble_size,
                shuffle_each_epoch=True,
                bootstrap_permutes=False,  # build bootstrap dataset using sampling with replacement
            )
                
            model_trainer.train(
                dataset_train, 
                dataset_val=dataset_val, 
                num_epochs=50, 
                patience=50, 
                callback=train_callback,
                silent=True)

        # --- Doing env step using the agent and adding to model dataset ---
        next_obs, reward, terminated, truncated, _ = common_util.step_env_and_add_to_buffer(
            env, obs, agent, {}, replay_buffer)
            
        # update_axes(
        #     axs, env.render(), ax_text, trial, steps_trial, all_rewards)
        
        obs = next_obs
        total_reward += reward
        steps_trial += 1

    env.end_simulation()
# Out:
# Connected!
# 36
# 41
# 46
# 51
# 60
# 65
# 70
# 75
# [[-5.69944914e-06 -8.30800191e-06 -1.06167517e-05 -1.28323220e-05
#   -8.72123690e-06 -8.76325081e-06 -8.78794478e-06 -8.79708311e-06]
#  [-1.69944994e-03 -1.73811867e-03 -1.75956167e-03 -1.76399384e-03
#    1.57925443e-03  1.57949495e-03  1.57957190e-03  1.57961916e-03]
#  [ 9.99998569e-01  9.99998569e-01  9.99998569e-01  9.99998331e-01
#    9.99998808e-01  9.99998808e-01  9.99998808e-01  9.99998808e-01]
#  [-3.51952303e-01 -3.51953149e-01 -2.51952173e-01 -2.51953194e-01
#    2.51560244e-01  2.51560235e-01  3.51561148e-01  3.51559343e-01]
#  [-4.99163478e-02  4.99115774e-02  5.00865350e-02 -5.00895522e-02
#   -5.00766815e-02  5.00811867e-02  4.99223779e-02 -4.99195262e-02]
#  [-5.00869093e-02  5.00839079e-02 -4.99146277e-02  4.99084812e-02
#   -4.99187873e-02  4.99231666e-02 -5.00758317e-02  5.00820118e-02]]
# 4 DoF [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# No propeller. Is it a magic box?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 41
#      32     model_trainer.train(
#      33         dataset_train,
#      34         dataset_val=dataset_val,
#    (...)
#      37         callback=train_callback,
#      38         silent=True)
#      40 # --- Doing env step using the agent and adding to model dataset ---
# ---> 41 next_obs, reward, terminated, truncated, _ = common_util.step_env_and_add_to_buffer(
#      42     env, obs, agent, {}, replay_buffer)
#      44 # update_axes(
#      45 #     axs, env.render(), ax_text, trial, steps_trial, all_rewards)
#      47 obs = next_obs
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\util\common.py:605, in step_env_and_add_to_buffer(env, obs, agent, agent_kwargs, replay_buffer, callback, agent_uses_low_dim_obs)
#     603 else:
#     604     agent_obs = obs
# --> 605 action = agent.act(agent_obs, **agent_kwargs)
#     606 next_obs, reward, terminated, truncated, info = env.step(action)
#     607 replay_buffer.add(obs, action, next_obs, reward, terminated, truncated)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\planning\trajectory_opt.py:684, in TrajectoryOptimizerAgent.act(self, obs, optimizer_callback, **_kwargs)
#     681     return self.trajectory_eval_fn(obs, action_sequences)
#     683 start_time = time.time()
# --> 684 plan = self.optimizer.optimize(
#     685     trajectory_eval_fn, callback=optimizer_callback
#     686 )
#     687 plan_time = time.time() - start_time
#     689 self.actions_to_use.extend([a for a in plan[: self.replan_freq]])
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\planning\trajectory_opt.py:558, in TrajectoryOptimizer.optimize(self, trajectory_eval_fn, callback)
#     539 def optimize(
#     540     self,
#     541     trajectory_eval_fn: Callable[[torch.Tensor], torch.Tensor],
#     542     callback: Optional[Callable] = None,
#     543 ) -> np.ndarray:
#     544     """Runs the trajectory optimization.
#     545
#     546     Args:
#    (...)
#     556         (tuple of np.ndarray and float): the best action sequence.
#     557     """
# --> 558     best_solution = self.optimizer.optimize(
#     559         trajectory_eval_fn,
#     560         x0=self.previous_solution,
#     561         callback=callback,
#     562     )
#     563     if self.keep_last_solution:
#     564         self.previous_solution = best_solution.roll(-self.replan_freq, dims=0)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\planning\trajectory_opt.py:172, in CEMOptimizer.optimize(self, obj_fun, x0, callback, **kwargs)
#     170 for i in range(self.num_iterations):
#     171     population = self._sample_population(mu, dispersion, population)
# --> 172     values = obj_fun(population)
#     174     if callback is not None:
#     175         callback(population, values, i)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\planning\trajectory_opt.py:681, in TrajectoryOptimizerAgent.act.<locals>.trajectory_eval_fn(action_sequences)
#     680 def trajectory_eval_fn(action_sequences):
# --> 681     return self.trajectory_eval_fn(obs, action_sequences)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\planning\trajectory_opt.py:744, in create_trajectory_optim_agent_for_model.<locals>.trajectory_eval_fn(initial_state, action_sequences)
#     743 def trajectory_eval_fn(initial_state, action_sequences):
# --> 744     return model_env.evaluate_action_sequences(
#     745         action_sequences, initial_state=initial_state, num_particles=num_particles
#     746     )
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\model_env.py:183, in ModelEnv.evaluate_action_sequences(self, action_sequences, initial_state, num_particles)
#     179 action_for_step = action_sequences[:, time_step, :]
#     180 action_batch = torch.repeat_interleave(
#     181     action_for_step, num_particles, dim=0
#     182 )
# --> 183 _, rewards, dones, model_state = self.step(
#     184     action_batch, model_state, sample=True
#     185 )
#     186 rewards[terminated] = 0
#     187 terminated |= dones
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\model_env.py:118, in ModelEnv.step(self, actions, model_state, sample)
#     111 if isinstance(actions, np.ndarray):
#     112     actions = torch.from_numpy(actions).to(self.device)
#     113 (
#     114     next_observs,
#     115     pred_rewards,
#     116     pred_terminals,
#     117     next_model_state,
# --> 118 ) = self.dynamics_model.sample(
#     119     actions,
#     120     model_state,
#     121     deterministic=not sample,
#     122     rng=self._rng,
#     123 )
#     124 rewards = (
#     125     pred_rewards
#     126     if self.reward_fn is None
#     127     else self.reward_fn(actions, next_observs)
#     128 )
#     129 dones = self.termination_fn(actions, next_observs)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\one_dim_tr_model.py:278, in OneDTransitionRewardModel.sample(self, act, model_state, deterministic, rng)
#     274 if not hasattr(self.model, "sample_1d"):
#     275     raise RuntimeError(
#     276         "OneDTransitionRewardModel requires wrapped model to define method sample_1d"
#     277     )
# --> 278 preds, next_model_state = self.model.sample_1d(
#     279     model_in, model_state, rng=rng, deterministic=deterministic
#     280 )
#     281 next_observs = preds[:, :-1] if self.learned_rewards else preds
#     282 if self.target_is_delta:
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\model.py:468, in Ensemble.sample_1d(self, model_input, model_state, deterministic, rng)
#     459     return (
#     460         self.forward(
#     461             model_input,
#    (...)
#     465         model_state,
#     466     )
#     467 assert rng is not None
# --> 468 means, logvars = self.forward(
#     469     model_input, rng=rng, propagation_indices=model_state["propagation_indices"]
#     470 )
#     471 variances = logvars.exp()
#     472 stds = torch.sqrt(variances)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\gaussian_mlp.py:278, in GaussianMLP.forward(self, x, rng, propagation_indices, use_propagation)
#     225 """Computes mean and logvar predictions for the given input.
#     226
#     227 When ``self.num_members > 1``, the model supports uncertainty propagation options
#    (...)
#     275
#     276 """
#     277 if use_propagation:
# --> 278     return self._forward_ensemble(
#     279         x, rng=rng, propagation_indices=propagation_indices
#     280     )
#     281 return self._default_forward(x)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\gaussian_mlp.py:212, in GaussianMLP._forward_ensemble(self, x, rng, propagation_indices)
#     208     if propagation_indices is None:
#     209         raise ValueError(
#     210             "When using propagation='fixed_model', `propagation_indices` must be provided."
#     211         )
# --> 212     return self._forward_from_indices(x, propagation_indices)
#     213 if self.propagation_method == "expectation":
#     214     mean, logvar = self._default_forward(x, only_elite=True)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\gaussian_mlp.py:168, in GaussianMLP._forward_from_indices(self, x, model_shuffle_indices)
#     161 num_models = (
#     162     len(self.elite_models) if self.elite_models is not None else len(self)
#     163 )
#     164 shuffled_x = x[:, model_shuffle_indices, ...].view(
#     165     num_models, batch_size // num_models, -1
#     166 )
# --> 168 mean, logvar = self._default_forward(shuffled_x, only_elite=True)
#     169 # note that mean and logvar are shuffled
#     170 mean = mean.view(batch_size, -1)
#
# File c:\users\ksubh\onedrive\documents\swarmslab_rl\summer 25\implementations\mbrl_lib\mbrl-lib\mbrl\models\gaussian_mlp.py:144, in GaussianMLP._default_forward(self, x, only_elite, **_kwargs)
#     140 def _default_forward(
#     141     self, x: torch.Tensor, only_elite: bool = False, **_kwargs
#     142 ) -> Tuple[torch.Tensor, Optional[torch.Tensor]]:
#     143     self._maybe_toggle_layers_use_only_elite(only_elite)
# --> 144     x = self.hidden_layers(x)
#     145     mean_and_logvar = self.mean_and_logvar(x)
#     146     self._maybe_toggle_layers_use_only_elite(only_elite)
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\modules\activation.py:799, in LeakyReLU.forward(self, input)
#     798 def forward(self, input: Tensor) -> Tensor:
# --> 799     return F.leaky_relu(input, self.negative_slope, self.inplace)
#
# File c:\Users\ksubh\anaconda3\envs\mbrl_py38\lib\site-packages\torch\nn\functional.py:1677, in leaky_relu(input, negative_slope, inplace)
#    1675     result = torch._C._nn.leaky_relu_(input, negative_slope)
#    1676 else:
# -> 1677     result = torch._C._nn.leaky_relu(input, negative_slope)
#    1678 return result
#
# KeyboardInterrupt:

# %%
        
        if steps_trial == trial_length:
            break
    
    all_rewards.append(total_reward)

update_axes(axs, env.render(), ax_text, trial, steps_trial, all_rewards, force_update=True)

# %% [markdown]
# Finally, below we check the results of the trainer callback, which show the training loss and validation score across all calls to ``model_trainer.train()``.

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))
ax[0].plot(train_losses)
ax[0].set_xlabel("Total training epochs")
ax[0].set_ylabel("Training loss (avg. NLL)")
ax[1].plot(val_scores)
ax[1].set_xlabel("Total training epochs")
ax[1].set_ylabel("Validation score (avg. MSE)")
plt.show()

# %% [markdown]
# # Where to learn more about MBRL?

# %% [markdown]
# To learn about the other features of the library, please check out our [documentation](https://facebookresearch.github.io/mbrl-lib/). Also take a look at our provided implementations of [PETS](https://github.com/facebookresearch/mbrl-lib/blob/main/mbrl/algorithms/pets.py), [MBPO](https://github.com/facebookresearch/mbrl-lib/blob/main/mbrl/algorithms/mbpo.py), and [PlaNet](https://github.com/facebookresearch/mbrl-lib/blob/main/mbrl/algorithms/planet.py), and their configuration [files](https://github.com/facebookresearch/mbrl-lib/tree/main/mbrl/examples/conf).
